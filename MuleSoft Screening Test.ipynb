# %% [markdown]
# ## SQLite Database Management

# %% [markdown]
# Create a database, store your interesting movie names with the names of lead actor, actress, year of release and the director name. Once you have stored the details, then use any programming language of your choice to retrieve the details.

# %% [markdown]
# #### Importing required libraries

# %%
import sqlite3 as sql
import pandas as pd

# %% [markdown]
# #### Creating new SQLite database

# %%
connection=sql.connect('movies_database.db')
cursor=connection.cursor()

# %%
cursor.execute("DROP TABLE IF EXISTS movies_database")

# %% [markdown]
# #### Creating new table - movies

# %%
table = """ CREATE TABLE movies(
            moiveName VARCHAR(50) NOT NULL,
            actorName CHAR(25) NOT NULL,
            actressName CHAR(25),
            yearOfRelease INT NOT NULL,
            directorName CHAR(25) NOT NULL
            );"""

# %%
cursor.execute(table)

# %%
query = ''' SELECT * FROM movies'''
df = pd.read_sql_query(query, connection)
df
# Out:
# Empty DataFrame
# Columns: [moiveName, actorName, actressName, yearOfRelease, directorName]
# Index: []

# %% [markdown]
# #### Inserting data into movies table

# %%
cursor.execute('''INSERT INTO movies VALUES ('The intern', 'Robert De Niro', 'Anne Hathaway', '2015','Nancy Meyers')''')
cursor.execute('''INSERT INTO movies VALUES ('Marvel- Shang-Chi and The Legend of The Ten Rings', 'Simu Liu', 'Awkwafina', '2021',' Destin Daniel Cretton')''')
cursor.execute('''INSERT INTO movies VALUES ('The Space Between Us', 'Asa Butterfield', 'Britt Robertson', '2017','Peter Chelsom')''')
cursor.execute('''INSERT INTO movies VALUES ('Marvel- Black Widow', '', 'Natasha Romanoff', '2021','Cate Shortland')''')
cursor.execute('''INSERT INTO movies VALUES ('The Midnight Sun', 'Patrick Schwarzenegger', 'Bella Thorne', '2018','Scott Speer')''')
cursor.execute('''INSERT INTO movies VALUES ('Ford vs Ferrari','Matt Damon,Christian Bale','','2019','James Mangold')''')
cursor.execute('''INSERT INTO movies VALUES ('Marvel- Eternals', 'Barry Keoghan, Richard Madden, Harry Styles','Angelina Jolie, Gemma Chan', '2021','Chloé Zhao')''')
cursor.execute('''INSERT INTO movies VALUES ('To All The Bright Places', 'Justice Smith', 'Elle Fanning', '2020','Brett Haley')''')
cursor.execute('''INSERT INTO movies VALUES ('Marvel- Spider Man No Way Home', 'Tom Holland', 'Zendaya', '2021 ','Jon Watts')''')
cursor.execute('''INSERT INTO movies VALUES ('The Adam Project', 'Ryan Reynolds, Walker Scobell, Mark Ruffalo', 'Jennifer Garner, Zoe Saldaña', '22','Shawn Levy')''')

# %% [markdown]
# #### Displaying the table after inserting the values

# %%
query = ''' SELECT * FROM movies'''
df = pd.read_sql_query(query, connection)
df
# Out:
#                                            moiveName  \
# 0                                         The intern
# 1  Marvel- Shang-Chi and The Legend of The Ten Rings
# 2                               The Space Between Us
# 3                                Marvel- Black Widow
# 4                                   The Midnight Sun
# 5                                    Ford vs Ferrari
# 6                                   Marvel- Eternals
# 7                           To All The Bright Places
# 8                     Marvel- Spider Man No Way Home
# 9                                   The Adam Project
#
#                                      actorName                   actressName  \
# 0                               Robert De Niro                 Anne Hathaway
# 1                                     Simu Liu                     Awkwafina
# 2                              Asa Butterfield               Britt Robertson
# 3                                                           Natasha Romanoff
# 4                       Patrick Schwarzenegger                  Bella Thorne
# 5                    Matt Damon,Christian Bale
# 6  Barry Keoghan, Richard Madden, Harry Styles    Angelina Jolie, Gemma Chan
# 7                                Justice Smith                  Elle Fanning
# 8                                  Tom Holland                       Zendaya
# 9  Ryan Reynolds, Walker Scobell, Mark Ruffalo  Jennifer Garner, Zoe Saldaña
#
#    yearOfRelease            directorName
# 0           2015            Nancy Meyers
# 1           2021   Destin Daniel Cretton
# 2           2017           Peter Chelsom
# 3           2021          Cate Shortland
# 4           2018             Scott Speer
# 5           2019           James Mangold
# 6           2021              Chloé Zhao
# 7           2020             Brett Haley
# 8           2021               Jon Watts
# 9             22              Shawn Levy

# %% [markdown]
# #### Query-1: Sorting the movies table by yearOfRelease

# %%
query1 = ''' SELECT * FROM movies ORDER BY 
    yearOfRelease DESC'''
df = pd.read_sql_query(query1, connection)
df
# Out:
#                                            moiveName  \
# 0  Marvel- Shang-Chi and The Legend of The Ten Rings
# 1                                Marvel- Black Widow
# 2                                   Marvel- Eternals
# 3                     Marvel- Spider Man No Way Home
# 4                           To All The Bright Places
# 5                                    Ford vs Ferrari
# 6                                   The Midnight Sun
# 7                               The Space Between Us
# 8                                         The intern
# 9                                   The Adam Project
#
#                                      actorName                   actressName  \
# 0                                     Simu Liu                     Awkwafina
# 1                                                           Natasha Romanoff
# 2  Barry Keoghan, Richard Madden, Harry Styles    Angelina Jolie, Gemma Chan
# 3                                  Tom Holland                       Zendaya
# 4                                Justice Smith                  Elle Fanning
# 5                    Matt Damon,Christian Bale
# 6                       Patrick Schwarzenegger                  Bella Thorne
# 7                              Asa Butterfield               Britt Robertson
# 8                               Robert De Niro                 Anne Hathaway
# 9  Ryan Reynolds, Walker Scobell, Mark Ruffalo  Jennifer Garner, Zoe Saldaña
#
#    yearOfRelease            directorName
# 0           2021   Destin Daniel Cretton
# 1           2021          Cate Shortland
# 2           2021              Chloé Zhao
# 3           2021               Jon Watts
# 4           2020             Brett Haley
# 5           2019           James Mangold
# 6           2018             Scott Speer
# 7           2017           Peter Chelsom
# 8           2015            Nancy Meyers
# 9             22              Shawn Levy

# %% [markdown]
# #### Query-2: Updating the movies table by yearOfRelease

# %%
cursor.execute('''UPDATE movies SET yearOfRelease = 2022 WHERE directorName == 'Shawn Levy' ''')
df = pd.read_sql_query("SELECT * FROM movies", connection)
df
# Out:
#                                            moiveName  \
# 0                                         The intern
# 1  Marvel- Shang-Chi and The Legend of The Ten Rings
# 2                               The Space Between Us
# 3                                Marvel- Black Widow
# 4                                   The Midnight Sun
# 5                                    Ford vs Ferrari
# 6                                   Marvel- Eternals
# 7                           To All The Bright Places
# 8                     Marvel- Spider Man No Way Home
# 9                                   The Adam Project
#
#                                      actorName                   actressName  \
# 0                               Robert De Niro                 Anne Hathaway
# 1                                     Simu Liu                     Awkwafina
# 2                              Asa Butterfield               Britt Robertson
# 3                                                           Natasha Romanoff
# 4                       Patrick Schwarzenegger                  Bella Thorne
# 5                    Matt Damon,Christian Bale
# 6  Barry Keoghan, Richard Madden, Harry Styles    Angelina Jolie, Gemma Chan
# 7                                Justice Smith                  Elle Fanning
# 8                                  Tom Holland                       Zendaya
# 9  Ryan Reynolds, Walker Scobell, Mark Ruffalo  Jennifer Garner, Zoe Saldaña
#
#    yearOfRelease            directorName
# 0           2015            Nancy Meyers
# 1           2021   Destin Daniel Cretton
# 2           2017           Peter Chelsom
# 3           2021          Cate Shortland
# 4           2018             Scott Speer
# 5           2019           James Mangold
# 6           2021              Chloé Zhao
# 7           2020             Brett Haley
# 8           2021               Jon Watts
# 9           2022              Shawn Levy

# %% [markdown]
# #### Query-3: Selecting the movies which has yearOfRelease <= 2020

# %%
query3 = ''' SELECT * FROM movies WHERE yearOfRelease <= 2020'''
df = pd.read_sql_query(query3, connection)
df
# Out:
#                   moiveName                  actorName      actressName  \
# 0                The intern             Robert De Niro    Anne Hathaway
# 1      The Space Between Us            Asa Butterfield  Britt Robertson
# 2          The Midnight Sun     Patrick Schwarzenegger     Bella Thorne
# 3           Ford vs Ferrari  Matt Damon,Christian Bale
# 4  To All The Bright Places              Justice Smith     Elle Fanning
#
#    yearOfRelease   directorName
# 0           2015   Nancy Meyers
# 1           2017  Peter Chelsom
# 2           2018    Scott Speer
# 3           2019  James Mangold
# 4           2020    Brett Haley

# %% [markdown]
# #### Query-4: Selecting the movies which has No Actor or Actress Name

# %%
query4 = ''' SELECT * FROM movies WHERE actorName ='' OR actressName =''  '''
df = pd.read_sql_query(query4, connection)
df
# Out:
#              moiveName                  actorName       actressName  \
# 0  Marvel- Black Widow                             Natasha Romanoff
# 1      Ford vs Ferrari  Matt Damon,Christian Bale
#
#    yearOfRelease    directorName
# 0           2021  Cate Shortland
# 1           2019   James Mangold

# %% [markdown]
# #### Query-5: Selecting the movie which was directed by Shawn Levy

# %%
query5 = ''' SELECT * FROM movies WHERE directorName == 'Shawn Levy' '''
df = pd.read_sql_query(query5, connection)
df
# Out:
#           moiveName                                    actorName  \
# 0  The Adam Project  Ryan Reynolds, Walker Scobell, Mark Ruffalo
#
#                     actressName  yearOfRelease directorName
# 0  Jennifer Garner, Zoe Saldaña           2022   Shawn Levy

# %% [markdown]
# #### Query-6: Selecting only Marvel movies from the table

# %%
query6 = '''SELECT * FROM movies WHERE moiveName LIKE '%Marvel%' '''
df = pd.read_sql_query(query6, connection)
df
# Out:
#                                            moiveName  \
# 0  Marvel- Shang-Chi and The Legend of The Ten Rings
# 1                                Marvel- Black Widow
# 2                                   Marvel- Eternals
# 3                     Marvel- Spider Man No Way Home
#
#                                      actorName                 actressName  \
# 0                                     Simu Liu                   Awkwafina
# 1                                                         Natasha Romanoff
# 2  Barry Keoghan, Richard Madden, Harry Styles  Angelina Jolie, Gemma Chan
# 3                                  Tom Holland                     Zendaya
#
#    yearOfRelease            directorName
# 0           2021   Destin Daniel Cretton
# 1           2021          Cate Shortland
# 2           2021              Chloé Zhao
# 3           2021               Jon Watts

# %% [markdown]
# #### Query-7: Deleting the movie  "Eternals"

# %%
cursor.execute('''DELETE FROM movies WHERE moiveName == 'Marvel- Eternals' ''')
df = pd.read_sql_query("SELECT * FROM movies", connection)
df
# Out:
#                                            moiveName  \
# 0                                         The intern
# 1  Marvel- Shang-Chi and The Legend of The Ten Rings
# 2                               The Space Between Us
# 3                                Marvel- Black Widow
# 4                                   The Midnight Sun
# 5                                    Ford vs Ferrari
# 6                           To All The Bright Places
# 7                     Marvel- Spider Man No Way Home
# 8                                   The Adam Project
#
#                                      actorName                   actressName  \
# 0                               Robert De Niro                 Anne Hathaway
# 1                                     Simu Liu                     Awkwafina
# 2                              Asa Butterfield               Britt Robertson
# 3                                                           Natasha Romanoff
# 4                       Patrick Schwarzenegger                  Bella Thorne
# 5                    Matt Damon,Christian Bale
# 6                                Justice Smith                  Elle Fanning
# 7                                  Tom Holland                       Zendaya
# 8  Ryan Reynolds, Walker Scobell, Mark Ruffalo  Jennifer Garner, Zoe Saldaña
#
#    yearOfRelease            directorName
# 0           2015            Nancy Meyers
# 1           2021   Destin Daniel Cretton
# 2           2017           Peter Chelsom
# 3           2021          Cate Shortland
# 4           2018             Scott Speer
# 5           2019           James Mangold
# 6           2020             Brett Haley
# 7           2021               Jon Watts
# 8           2022              Shawn Levy
